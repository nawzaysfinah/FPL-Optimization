# %%
import pandas as pd
import sasoptpy as so 
#Sertelp goes to FPLReview.com to get the .csv data

# %%
df = pd.read_csv('../data/fpl_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 second_name     team  element_type  selected_by_percent  \
# 0           0       Xhaka  Arsenal             3                  2.6
# 1           1      Elneny  Arsenal             3                  0.6
# 2           2     Holding  Arsenal             2                  0.1
# 3           3      Partey  Arsenal             3                  0.4
# 4           4    Ødegaard  Arsenal             3                 37.3
#
#    now_cost  minutes  transfers_in  value_season  total_points    position  \
# 0        49     2113        845792          19.2            94  Midfielder
# 1        41      111        198337           1.5             6  Midfielder
# 2        42       17          7171           1.7             7    Defender
# 3        47     1681        101282          14.3            67  Midfielder
# 4        70     2131       5467369          20.6           144  Midfielder
#
#    value
# 0   19.2
# 1    1.5
# 2    1.7
# 3   14.3
# 4   20.6

# %%
gk_data = df[df['position'] == 'Goalkeeper'].copy().reset_index()

# %%
gk_data.head()
# Out:
#    index  Unnamed: 0      second_name         team  element_type  \
# 0     11          12         Ramsdale      Arsenal             1
# 1     24          35  Martínez Romero  Aston Villa             1
# 2     27          39            Olsen  Aston Villa             1
# 3     60          87          Travers  Bournemouth             1
# 4     68          98      Murara Neto  Bournemouth             1
#
#    selected_by_percent  now_cost  minutes  transfers_in  value_season  \
# 0                 12.1        49     2340       1469716          21.0
# 1                  4.4        49     2014        579222          15.9
# 2                  1.6        39      235        114676           2.3
# 3                  0.4        42      945         63760           6.0
# 4                  0.2        45     1305         60431          10.4
#
#    total_points    position  value
# 0           103  Goalkeeper   21.0
# 1            78  Goalkeeper   15.9
# 2             9  Goalkeeper    2.3
# 3            25  Goalkeeper    6.0
# 4            47  Goalkeeper   10.4

# %%
model = so.Model(name='gk_model')
# Out:
# NOTE: Initialized model gk_model.

# %%
gk_data.set_index('index', inplace = True)

# %%
gk_data.head()
# Out:
#        Unnamed: 0      second_name         team  element_type  \
# index
# 11             12         Ramsdale      Arsenal             1
# 24             35  Martínez Romero  Aston Villa             1
# 27             39            Olsen  Aston Villa             1
# 60             87          Travers  Bournemouth             1
# 68             98      Murara Neto  Bournemouth             1
#
#        selected_by_percent  now_cost  minutes  transfers_in  value_season  \
# index
# 11                    12.1        49     2340       1469716          21.0
# 24                     4.4        49     2014        579222          15.9
# 27                     1.6        39      235        114676           2.3
# 60                     0.4        42      945         63760           6.0
# 68                     0.2        45     1305         60431          10.4
#
#        total_points    position  value
# index
# 11              103  Goalkeeper   21.0
# 24               78  Goalkeeper   15.9
# 27                9  Goalkeeper    2.3
# 60               25  Goalkeeper    6.0
# 68               47  Goalkeeper   10.4

# %%
players = gk_data.index.tolist()

# %%
players
# Out:
# [11,
#  24,
#  27,
#  60,
#  68,
#  78,
#  101,
#  108,
#  129,
#  139,
#  156,
#  180,
#  185,
#  206,
#  217,
#  237,
#  271,
#  294,
#  321,
#  337,
#  364,
#  382,
#  399,
#  404,
#  416,
#  436,
#  448,
#  449,
#  476,
#  490,
#  502]

# %%
lineup = model.add_variables(players, name='lineup', vartype=so.binary)

# %%
lineup[11]
# Out:
# sasoptpy.Variable(name='lineup[11]', lb=0, ub=1, vartype='BIN')

# %%
bench = model.add_variables(players, name='bench',vartype=so.binary)

# %%
total_xp = so.expr_sum(lineup[p] * gk_data.loc[p, 'value_season'] for p in players) + 0.1 * (so.expr_sum(bench[p] * gk_data.loc[p, 'value_season'] for p in players))

# %%
total_xp
# Out:
# sasoptpy.Expression(exp = 21.0 * lineup[11] + 15.9 * lineup[24] + 2.3 * lineup[27] + 6.0 * lineup[60] + 10.4 * lineup[68] + 22.7 * lineup[78] + 1.5 * lineup[101] + 17.6 * lineup[108] + 17.9 * lineup[129] + 4.8 * lineup[139] + 21.4 * lineup[156] + 2.3 * lineup[180] + 17.5 * lineup[185] + 22.4 * lineup[206] + 1.6 * lineup[217] + 22.2 * lineup[237] + 17.8 * lineup[271] + 21.7 * lineup[294] + 17.0 * lineup[321] + 19.2 * lineup[337] + 2.0 * lineup[364] + 19.6 * lineup[382] + 17.8 * lineup[399] + lineup[404] + 3.3 * lineup[416] + 15.6 * lineup[436] + 15.2 * lineup[448] + 4.4 * lineup[449] + 17.2 * lineup[476] + 0.9 * lineup[490] + 21.6 * lineup[502] + 2.1 * bench[11] + 1.59 * bench[24] + 0.23 * bench[27] + 0.6 * bench[60] + 1.04 * bench[68] + 2.27 * bench[78] + 0.15 * bench[101] + 1.76 * bench[108] + 1.79 * bench[129] + 0.48 * bench[139] + 2.14 * bench[156] + 0.23 * bench[180] + 1.75 * bench[185] + 2.24 * bench[206] + 0.16 * bench[217] + 2.22 * bench[237] + 1.78 * bench[271] + 2.17 * bench[294] + 1.7 * bench[321] + 1.92 * bench[337] + 0.2 * bench[364] + 1.96 * bench[382] + 1.78 * bench[399] + 0.1 * bench[404] + 0.33 * bench[416] + 1.56 * bench[436] + 1.52 * bench[448] + 0.44 * bench[449] + 1.72 * bench[476] + 0.09 * bench[490] + 2.16 * bench[502], name=None)

# %%
model.set_objective(total_xp, name='total_xp_obj', sense=so.maximize)
# Out:
# sasoptpy.Expression(exp = 21.0 * lineup[11] + 15.9 * lineup[24] + 2.3 * lineup[27] + 6.0 * lineup[60] + 10.4 * lineup[68] + 22.7 * lineup[78] + 1.5 * lineup[101] + 17.6 * lineup[108] + 17.9 * lineup[129] + 4.8 * lineup[139] + 21.4 * lineup[156] + 2.3 * lineup[180] + 17.5 * lineup[185] + 22.4 * lineup[206] + 1.6 * lineup[217] + 22.2 * lineup[237] + 17.8 * lineup[271] + 21.7 * lineup[294] + 17.0 * lineup[321] + 19.2 * lineup[337] + 2.0 * lineup[364] + 19.6 * lineup[382] + 17.8 * lineup[399] + lineup[404] + 3.3 * lineup[416] + 15.6 * lineup[436] + 15.2 * lineup[448] + 4.4 * lineup[449] + 17.2 * lineup[476] + 0.9 * lineup[490] + 21.6 * lineup[502] + 2.1 * bench[11] + 1.59 * bench[24] + 0.23 * bench[27] + 0.6 * bench[60] + 1.04 * bench[68] + 2.27 * bench[78] + 0.15 * bench[101] + 1.76 * bench[108] + 1.79 * bench[129] + 0.48 * bench[139] + 2.14 * bench[156] + 0.23 * bench[180] + 1.75 * bench[185] + 2.24 * bench[206] + 0.16 * bench[217] + 2.22 * bench[237] + 1.78 * bench[271] + 2.17 * bench[294] + 1.7 * bench[321] + 1.92 * bench[337] + 0.2 * bench[364] + 1.96 * bench[382] + 1.78 * bench[399] + 0.1 * bench[404] + 0.33 * bench[416] + 1.56 * bench[436] + 1.52 * bench[448] + 0.44 * bench[449] + 1.72 * bench[476] + 0.09 * bench[490] + 2.16 * bench[502], name='total_xp_obj')

# %%
model.add_constraints((lineup[p]+ bench[p] <= 1 for p in players), name='lineup_or_bench');

# %%
model.add_constraint(so.expr_sum(lineup[p] for p in players) ==1, name = 'single_lineup');

# %%
model.add_constraint(so.expr_sum(bench[p] for p in players) ==1, name = 'single_bench');

# %%
budget = 92
model.add_constraint(so.expr_sum((lineup[p] + bench [p]) * gk_data.loc[p,'now_cost'] for p in players) <= budget, name='budget_con')
# Out:
# sasoptpy.Constraint(49 * lineup[11] + 49 * bench[11] + 49 * lineup[24] + 49 * bench[24] + 39 * lineup[27] + 39 * bench[27] + 42 * lineup[60] + 42 * bench[60] + 45 * lineup[68] + 45 * bench[68] + 48 * lineup[78] + 48 * bench[78] + 39 * lineup[101] + 39 * bench[101] + 46 * lineup[108] + 46 * bench[108] + 47 * lineup[129] + 47 * bench[129] + 48 * lineup[139] + 48 * bench[139] + 44 * lineup[156] + 44 * bench[156] + 39 * lineup[180] + 39 * bench[180] + 44 * lineup[185] + 44 * bench[185] + 45 * lineup[206] + 45 * bench[206] + 43 * lineup[217] + 43 * bench[217] + 40 * lineup[237] + 40 * bench[237] + 45 * lineup[271] + 45 * bench[271] + 54 * lineup[294] + 54 * bench[294] + 54 * lineup[321] + 54 * bench[321] + 50 * lineup[337] + 50 * bench[337] + 41 * lineup[364] + 41 * bench[364] + 54 * lineup[382] + 54 * bench[382] + 46 * lineup[399] + 46 * bench[399] + 39 * lineup[404] + 39 * bench[404] + 45 * lineup[416] + 45 * bench[416] + 45 * lineup[436] + 45 * bench[436] + 54 * lineup[448] + 54 * bench[448] + 39 * lineup[449] + 39 * bench[449] + 50 * lineup[476] + 50 * bench[476] + 43 * lineup[490] + 43 * bench[490] + 50 * lineup[502] + 50 * bench[502] <=  92, name='budget_con')

# %%
print(model.export_mps(fetch=True))
# Out:
# NAME    gk_model
# ROWS
#  MAX    total_xp_obj
#  L      lineup_or_bench[11]
#  L      lineup_or_bench[24]
#  L      lineup_or_bench[27]
#  L      lineup_or_bench[60]
#  L      lineup_or_bench[68]
#  L      lineup_or_bench[78]
#  L      lineup_or_bench[101]
#  L      lineup_or_bench[108]
#  L      lineup_or_bench[129]
#  L      lineup_or_bench[139]
#  L      lineup_or_bench[156]
#  L      lineup_or_bench[180]
#  L      lineup_or_bench[185]
#  L      lineup_or_bench[206]
#  L      lineup_or_bench[217]
#  L      lineup_or_bench[237]
#  L      lineup_or_bench[271]
#  L      lineup_or_bench[294]
#  L      lineup_or_bench[321]
#  L      lineup_or_bench[337]
#  L      lineup_or_bench[364]
#  L      lineup_or_bench[382]
#  L      lineup_or_bench[399]
#  L      lineup_or_bench[404]
#  L      lineup_or_bench[416]
#  L      lineup_or_bench[436]
#  L      lineup_or_bench[448]
#  L      lineup_or_bench[449]
#  L      lineup_or_bench[476]
#  L      lineup_or_bench[490]
#  L      lineup_or_bench[502]
#  E      single_lineup
#  E      single_bench
#  L      budget_con
# COLUMNS
#         lineup[11]           total_xp_obj         21.00 lineup_or_bench[11]   1.0
#         lineup[11]           single_lineup         1.00 budget_con           49.0
#         lineup[24]           total_xp_obj         15.90 lineup_or_bench[24]   1.0
#         lineup[24]           single_lineup         1.00 budget_con           49.0
#         lineup[27]           total_xp_obj          2.30 lineup_or_bench[27]   1.0
#         lineup[27]           single_lineup         1.00 budget_con           39.0
#         lineup[60]           total_xp_obj          6.00 lineup_or_bench[60]   1.0
#         lineup[60]           single_lineup         1.00 budget_con           42.0
#         lineup[68]           total_xp_obj         10.40 lineup_or_bench[68]   1.0
#         lineup[68]           single_lineup         1.00 budget_con           45.0
#         lineup[78]           total_xp_obj         22.70 lineup_or_bench[78]   1.0
#         lineup[78]           single_lineup         1.00 budget_con           48.0
#         lineup[101]          total_xp_obj          1.50 lineup_or_bench[101]  1.0
#         lineup[101]          single_lineup         1.00 budget_con           39.0
#         lineup[108]          total_xp_obj         17.60 lineup_or_bench[108]  1.0
#         lineup[108]          single_lineup         1.00 budget_con           46.0
#         lineup[129]          total_xp_obj         17.90 lineup_or_bench[129]  1.0
#         lineup[129]          single_lineup         1.00 budget_con           47.0
#         lineup[139]          total_xp_obj          4.80 lineup_or_bench[139]  1.0
#         lineup[139]          single_lineup         1.00 budget_con           48.0
#         lineup[156]          total_xp_obj         21.40 lineup_or_bench[156]  1.0
#         lineup[156]          single_lineup         1.00 budget_con           44.0
#         lineup[180]          total_xp_obj          2.30 lineup_or_bench[180]  1.0
#         lineup[180]          single_lineup         1.00 budget_con           39.0
#         lineup[185]          total_xp_obj         17.50 lineup_or_bench[185]  1.0
#         lineup[185]          single_lineup         1.00 budget_con           44.0
#         lineup[206]          total_xp_obj         22.40 lineup_or_bench[206]  1.0
#         lineup[206]          single_lineup         1.00 budget_con           45.0
#         lineup[217]          total_xp_obj          1.60 lineup_or_bench[217]  1.0
#         lineup[217]          single_lineup         1.00 budget_con           43.0
#         lineup[237]          total_xp_obj         22.20 lineup_or_bench[237]  1.0
#         lineup[237]          single_lineup         1.00 budget_con           40.0
#         lineup[271]          total_xp_obj         17.80 lineup_or_bench[271]  1.0
#         lineup[271]          single_lineup         1.00 budget_con           45.0
#         lineup[294]          total_xp_obj         21.70 lineup_or_bench[294]  1.0
#         lineup[294]          single_lineup         1.00 budget_con           54.0
#         lineup[321]          total_xp_obj         17.00 lineup_or_bench[321]  1.0
#         lineup[321]          single_lineup         1.00 budget_con           54.0
#         lineup[337]          total_xp_obj         19.20 lineup_or_bench[337]  1.0
#         lineup[337]          single_lineup         1.00 budget_con           50.0
#         lineup[364]          total_xp_obj          2.00 lineup_or_bench[364]  1.0
#         lineup[364]          single_lineup         1.00 budget_con           41.0
#         lineup[382]          total_xp_obj         19.60 lineup_or_bench[382]  1.0
#         lineup[382]          single_lineup         1.00 budget_con           54.0
#         lineup[399]          total_xp_obj         17.80 lineup_or_bench[399]  1.0
#         lineup[399]          single_lineup         1.00 budget_con           46.0
#         lineup[404]          total_xp_obj          1.00 lineup_or_bench[404]  1.0
#         lineup[404]          single_lineup         1.00 budget_con           39.0
#         lineup[416]          total_xp_obj          3.30 lineup_or_bench[416]  1.0
#         lineup[416]          single_lineup         1.00 budget_con           45.0
#         lineup[436]          total_xp_obj         15.60 lineup_or_bench[436]  1.0
#         lineup[436]          single_lineup         1.00 budget_con           45.0
#         lineup[448]          total_xp_obj         15.20 lineup_or_bench[448]  1.0
#         lineup[448]          single_lineup         1.00 budget_con           54.0
#         lineup[449]          total_xp_obj          4.40 lineup_or_bench[449]  1.0
#         lineup[449]          single_lineup         1.00 budget_con           39.0
#         lineup[476]          total_xp_obj         17.20 lineup_or_bench[476]  1.0
#         lineup[476]          single_lineup         1.00 budget_con           50.0
#         lineup[490]          total_xp_obj          0.90 lineup_or_bench[490]  1.0
#         lineup[490]          single_lineup         1.00 budget_con           43.0
#         lineup[502]          total_xp_obj         21.60 lineup_or_bench[502]  1.0
#         lineup[502]          single_lineup         1.00 budget_con           50.0
#         bench[11]            total_xp_obj          2.10 lineup_or_bench[11]   1.0
#         bench[11]            single_bench          1.00 budget_con           49.0
#         bench[24]            total_xp_obj          1.59 lineup_or_bench[24]   1.0
#         bench[24]            single_bench          1.00 budget_con           49.0
#         bench[27]            total_xp_obj          0.23 lineup_or_bench[27]   1.0
#         bench[27]            single_bench          1.00 budget_con           39.0
#         bench[60]            total_xp_obj          0.60 lineup_or_bench[60]   1.0
#         bench[60]            single_bench          1.00 budget_con           42.0
#         bench[68]            total_xp_obj          1.04 lineup_or_bench[68]   1.0
#         bench[68]            single_bench          1.00 budget_con           45.0
#         bench[78]            total_xp_obj          2.27 lineup_or_bench[78]   1.0
#         bench[78]            single_bench          1.00 budget_con           48.0
#         bench[101]           total_xp_obj          0.15 lineup_or_bench[101]  1.0
#         bench[101]           single_bench          1.00 budget_con           39.0
#         bench[108]           total_xp_obj          1.76 lineup_or_bench[108]  1.0
#         bench[108]           single_bench          1.00 budget_con           46.0
#         bench[129]           total_xp_obj          1.79 lineup_or_bench[129]  1.0
#         bench[129]           single_bench          1.00 budget_con           47.0
#         bench[139]           total_xp_obj          0.48 lineup_or_bench[139]  1.0
#         bench[139]           single_bench          1.00 budget_con           48.0
#         bench[156]           total_xp_obj          2.14 lineup_or_bench[156]  1.0
#         bench[156]           single_bench          1.00 budget_con           44.0
#         bench[180]           total_xp_obj          0.23 lineup_or_bench[180]  1.0
#         bench[180]           single_bench          1.00 budget_con           39.0
#         bench[185]           total_xp_obj          1.75 lineup_or_bench[185]  1.0
#         bench[185]           single_bench          1.00 budget_con           44.0
#         bench[206]           total_xp_obj          2.24 lineup_or_bench[206]  1.0
#         bench[206]           single_bench          1.00 budget_con           45.0
#         bench[217]           total_xp_obj          0.16 lineup_or_bench[217]  1.0
#         bench[217]           single_bench          1.00 budget_con           43.0
#         bench[237]           total_xp_obj          2.22 lineup_or_bench[237]  1.0
#         bench[237]           single_bench          1.00 budget_con           40.0
#         bench[271]           total_xp_obj          1.78 lineup_or_bench[271]  1.0
#         bench[271]           single_bench          1.00 budget_con           45.0
#         bench[294]           total_xp_obj          2.17 lineup_or_bench[294]  1.0
#         bench[294]           single_bench          1.00 budget_con           54.0
#         bench[321]           total_xp_obj          1.70 lineup_or_bench[321]  1.0
#         bench[321]           single_bench          1.00 budget_con           54.0
#         bench[337]           total_xp_obj          1.92 lineup_or_bench[337]  1.0
#         bench[337]           single_bench          1.00 budget_con           50.0
#         bench[364]           total_xp_obj          0.20 lineup_or_bench[364]  1.0
#         bench[364]           single_bench          1.00 budget_con           41.0
#         bench[382]           total_xp_obj          1.96 lineup_or_bench[382]  1.0
#         bench[382]           single_bench          1.00 budget_con           54.0
#         bench[399]           total_xp_obj          1.78 lineup_or_bench[399]  1.0
#         bench[399]           single_bench          1.00 budget_con           46.0
#         bench[404]           total_xp_obj          0.10 lineup_or_bench[404]  1.0
#         bench[404]           single_bench          1.00 budget_con           39.0
#         bench[416]           total_xp_obj          0.33 lineup_or_bench[416]  1.0
#         bench[416]           single_bench          1.00 budget_con           45.0
#         bench[436]           total_xp_obj          1.56 lineup_or_bench[436]  1.0
#         bench[436]           single_bench          1.00 budget_con           45.0
#         bench[448]           total_xp_obj          1.52 lineup_or_bench[448]  1.0
#         bench[448]           single_bench          1.00 budget_con           54.0
#         bench[449]           total_xp_obj          0.44 lineup_or_bench[449]  1.0
#         bench[449]           single_bench          1.00 budget_con           39.0
#         bench[476]           total_xp_obj          1.72 lineup_or_bench[476]  1.0
#         bench[476]           single_bench          1.00 budget_con           50.0
#         bench[490]           total_xp_obj          0.09 lineup_or_bench[490]  1.0
#         bench[490]           single_bench          1.00 budget_con           43.0
#         bench[502]           total_xp_obj          2.16 lineup_or_bench[502]  1.0
#         bench[502]           single_bench          1.00 budget_con           50.0
# RHS
#         RHS                  lineup_or_bench[11]   1.00 lineup_or_bench[24]   1.0
#         RHS                  lineup_or_bench[27]   1.00 lineup_or_bench[60]   1.0
#         RHS                  lineup_or_bench[68]   1.00 lineup_or_bench[78]   1.0
#         RHS                  lineup_or_bench[101]  1.00 lineup_or_bench[108]  1.0
#         RHS                  lineup_or_bench[129]  1.00 lineup_or_bench[139]  1.0
#         RHS                  lineup_or_bench[156]  1.00 lineup_or_bench[180]  1.0
#         RHS                  lineup_or_bench[185]  1.00 lineup_or_bench[206]  1.0
#         RHS                  lineup_or_bench[217]  1.00 lineup_or_bench[237]  1.0
#         RHS                  lineup_or_bench[271]  1.00 lineup_or_bench[294]  1.0
#         RHS                  lineup_or_bench[321]  1.00 lineup_or_bench[337]  1.0
#         RHS                  lineup_or_bench[364]  1.00 lineup_or_bench[382]  1.0
#         RHS                  lineup_or_bench[399]  1.00 lineup_or_bench[404]  1.0
#         RHS                  lineup_or_bench[416]  1.00 lineup_or_bench[436]  1.0
#         RHS                  lineup_or_bench[448]  1.00 lineup_or_bench[449]  1.0
#         RHS                  lineup_or_bench[476]  1.00 lineup_or_bench[490]  1.0
#         RHS                  lineup_or_bench[502]  1.00 single_lineup         1.0
#         RHS                  single_bench          1.00 budget_con           92.0
# RANGES
# BOUNDS
#  BV     BND                  lineup[11]            1.00
#  BV     BND                  lineup[24]            1.00
#  BV     BND                  lineup[27]            1.00
#  BV     BND                  lineup[60]            1.00
#  BV     BND                  lineup[68]            1.00
#  BV     BND                  lineup[78]            1.00
#  BV     BND                  lineup[101]           1.00
#  BV     BND                  lineup[108]           1.00
#  BV     BND                  lineup[129]           1.00
#  BV     BND                  lineup[139]           1.00
#  BV     BND                  lineup[156]           1.00
#  BV     BND                  lineup[180]           1.00
#  BV     BND                  lineup[185]           1.00
#  BV     BND                  lineup[206]           1.00
#  BV     BND                  lineup[217]           1.00
#  BV     BND                  lineup[237]           1.00
#  BV     BND                  lineup[271]           1.00
#  BV     BND                  lineup[294]           1.00
#  BV     BND                  lineup[321]           1.00
#  BV     BND                  lineup[337]           1.00
#  BV     BND                  lineup[364]           1.00
#  BV     BND                  lineup[382]           1.00
#  BV     BND                  lineup[399]           1.00
#  BV     BND                  lineup[404]           1.00
#  BV     BND                  lineup[416]           1.00
#  BV     BND                  lineup[436]           1.00
#  BV     BND                  lineup[448]           1.00
#  BV     BND                  lineup[449]           1.00
#  BV     BND                  lineup[476]           1.00
#  BV     BND                  lineup[490]           1.00
#  BV     BND                  lineup[502]           1.00
#  BV     BND                  bench[11]             1.00
#  BV     BND                  bench[24]             1.00
#  BV     BND                  bench[27]             1.00
#  BV     BND                  bench[60]             1.00
#  BV     BND                  bench[68]             1.00
#  BV     BND                  bench[78]             1.00
#  BV     BND                  bench[101]            1.00
#  BV     BND                  bench[108]            1.00
#  BV     BND                  bench[129]            1.00
#  BV     BND                  bench[139]            1.00
#  BV     BND                  bench[156]            1.00
#  BV     BND                  bench[180]            1.00
#  BV     BND                  bench[185]            1.00
#  BV     BND                  bench[206]            1.00
#  BV     BND                  bench[217]            1.00
#  BV     BND                  bench[237]            1.00
#  BV     BND                  bench[271]            1.00
#  BV     BND                  bench[294]            1.00
#  BV     BND                  bench[321]            1.00
#  BV     BND                  bench[337]            1.00
#  BV     BND                  bench[364]            1.00
#  BV     BND                  bench[382]            1.00
#  BV     BND                  bench[399]            1.00
#  BV     BND                  bench[404]            1.00
#  BV     BND                  bench[416]            1.00
#  BV     BND                  bench[436]            1.00
#  BV     BND                  bench[448]            1.00
#  BV     BND                  bench[449]            1.00
#  BV     BND                  bench[476]            1.00
#  BV     BND                  bench[490]            1.00
#  BV     BND                  bench[502]            1.00
# ENDATA

# %%
model.set_objective(-total_xp, name='total_xp_obj', sense='N')
# Out:
# sasoptpy.Expression(exp = - 21.0 * lineup[11] - 15.9 * lineup[24] - 2.3 * lineup[27] - 6.0 * lineup[60] - 10.4 * lineup[68] - 22.7 * lineup[78] - 1.5 * lineup[101] - 17.6 * lineup[108] - 17.9 * lineup[129] - 4.8 * lineup[139] - 21.4 * lineup[156] - 2.3 * lineup[180] - 17.5 * lineup[185] - 22.4 * lineup[206] - 1.6 * lineup[217] - 22.2 * lineup[237] - 17.8 * lineup[271] - 21.7 * lineup[294] - 17.0 * lineup[321] - 19.2 * lineup[337] - 2.0 * lineup[364] - 19.6 * lineup[382] - 17.8 * lineup[399] - lineup[404] - 3.3 * lineup[416] - 15.6 * lineup[436] - 15.2 * lineup[448] - 4.4 * lineup[449] - 17.2 * lineup[476] - 0.9 * lineup[490] - 21.6 * lineup[502] - 2.1 * bench[11] - 1.59 * bench[24] - 0.23 * bench[27] - 0.6 * bench[60] - 1.04 * bench[68] - 2.27 * bench[78] - 0.15 * bench[101] - 1.76 * bench[108] - 1.79 * bench[129] - 0.48 * bench[139] - 2.14 * bench[156] - 0.23 * bench[180] - 1.75 * bench[185] - 2.24 * bench[206] - 0.16 * bench[217] - 2.22 * bench[237] - 1.78 * bench[271] - 2.17 * bench[294] - 1.7 * bench[321] - 1.92 * bench[337] - 0.2 * bench[364] - 1.96 * bench[382] - 1.78 * bench[399] - 0.1 * bench[404] - 0.33 * bench[416] - 1.56 * bench[436] - 1.52 * bench[448] - 0.44 * bench[449] - 1.72 * bench[476] - 0.09 * bench[490] - 2.16 * bench[502], name='total_xp_obj')

# %%
model.export_mps(filename='gk.mps')

# %%
command = 'cbc gk.mps solve solu solution.txt'

# %%
# !{command}
# Out:
# Welcome to the CBC MILP Solver
# Version: devel
# Build Date: Apr 27 2021
#
# command line - cbc gk.mps solve solu solution.txt (default strategy 1)
# At line 1 NAME    gk_model
# At line 2 ROWS
# At line 38 COLUMNS
# At line 163 RHS
# At line 181 RANGES
# At line 182 BOUNDS
# At line 245 ENDATA
# Problem gk_model has 34 rows, 62 columns and 186 elements
# Coin0008I gk_model read with 0 errors
# Continuous objective value is -24.936 - 0.01 seconds
# Cgl0003I 8 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0005I 2 SOS with 52 members
# Cgl0004I processed model has 30 rows, 52 columns (52 integer (52 of which binary)) and 302 elements
# Coin3009W Conflict graph built in 0.003 seconds, density: 16.154%
# Cgl0015I Clique Strengthening extended 9 cliques, 15 were dominated
# After applying Clique Strengthening continuous objective value is -24.92
# Cutoff increment increased from 0.0001 to 0.00999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -24.92
# Cbc0038I Before mini branch and bound, 52 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.31 seconds)
# Cbc0038I After 0.31 seconds - Feasibility pump exiting with objective of -24.92 - took 0.00 seconds
# Cbc0012I Integer solution of -24.92 found by feasibility pump after 0 iterations and 0 nodes (0.31 seconds)
# Cbc0001I Search completed - best objective -24.92, took 0 iterations and 0 nodes (0.31 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -24.92 to -24.92
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -24.92000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.34
# Time (Wallclock seconds):       0.34
#
# Total time (CPU seconds):       0.35   (Wallclock seconds):       0.35

# %%
with open('solution.txt', 'r') as f:
    for v in model.get_variables():
        v.set_value(0)
    for line in f:
        if 'objective value' in line:
            continue
        words = line.split()
        var = model.get_variable(words[1])
        var.set_value(float(words[2]))

# %%
print("LINEUP")
for p in players:
    if lineup[p].get_value() > 0.5:
        print(p,gk_data.loc[p])
        
print("BENCH")
for p in players:
    if bench[p].get_value() > 0.5:
        print(p,gk_data.loc[p])
# Out:
# LINEUP
# 78 Unnamed: 0                     117
# second_name            Raya Martin
# team                     Brentford
# element_type                     1
# selected_by_percent           13.9
# now_cost                        48
# minutes                       2160
# transfers_in               2007799
# value_season                  22.7
# total_points                   109
# position                Goalkeeper
# value                         22.7
# Name: 78, dtype: object
# BENCH
# 237 Unnamed: 0                    349
# second_name                  Ward
# team                    Leicester
# element_type                    1
# selected_by_percent          25.6
# now_cost                       40
# minutes                      2250
# transfers_in              2312609
# value_season                 22.2
# total_points                   89
# position               Goalkeeper
# value                        22.2
# Name: 237, dtype: object
